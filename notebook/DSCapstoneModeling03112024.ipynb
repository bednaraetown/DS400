# %%
import pandas as pd
df = pd.read_csv("nba_games.csv", index_col=0)
df
# Out:
#           mp   mp.1    fg    fga    fg%    3p   3pa    3p%    ft   fta  ...  \
# 0      240.0  240.0  39.0   81.0  0.481   6.0  20.0  0.300  14.0  18.0  ...
# 1      240.0  240.0  36.0  100.0  0.360   7.0  31.0  0.226  16.0  19.0  ...
# 2      240.0  240.0  37.0   85.0  0.435   8.0  19.0  0.421  17.0  23.0  ...
# 3      240.0  240.0  41.0   89.0  0.461   8.0  21.0  0.381  17.0  19.0  ...
# 4      240.0  240.0  27.0   86.0  0.314   6.0  26.0  0.231  15.0  20.0  ...
# ...      ...    ...   ...    ...    ...   ...   ...    ...   ...   ...  ...
# 17767  240.0  240.0  35.0   81.0  0.432  11.0  26.0  0.423  27.0  36.0  ...
# 17768  240.0  240.0  37.0   74.0  0.500  13.0  25.0  0.520  26.0  37.0  ...
# 17769  240.0  240.0  42.0   89.0  0.472  14.0  33.0  0.424  10.0  20.0  ...
# 17770  240.0  240.0  41.0   85.0  0.482   9.0  26.0  0.346  26.0  30.0  ...
# 17771  240.0  240.0  33.0   85.0  0.388  12.0  44.0  0.273  28.0  34.0  ...
#
# ...

# %%
df = df.sort_values("date")

# %%
df = df.reset_index(drop=True)

# %%
del df["mp.1"]
del df["mp_opp.1"]
del df["index_opp"]

# %%
df.shape
# Out:
# (17772, 147)

# %%
df.describe()
# Out:
#                  mp            fg           fga           fg%            3p  \
# count  17772.000000  17772.000000  17772.000000  17772.000000  17772.000000
# mean     241.564258     39.954817     87.020538      0.460049     11.022901
# std        7.002952      5.225686      7.233960      0.054656      3.961903
# min      240.000000     19.000000     60.000000      0.269000      0.000000
# 25%      240.000000     36.000000     82.000000      0.422000      8.000000
# 50%      240.000000     40.000000     87.000000      0.459000     11.000000
# 75%      240.000000     43.000000     92.000000      0.495000     14.000000
# max      340.000000     63.000000    128.000000      0.687000     29.000000
#
#                 3pa           3p%            ft           fta           ft%  \
# count  17772.000000  17772.000000  17772.000000  17772.000000  17772.000000
# mean      30.800923      0.356935     17.415710     22.627279      0.770461
# ...

# %%
def add_target(group):
    group["target"] = group["won"].shift(-1)
    return group

df = df.groupby("team", group_keys=False).apply(add_target)

# %%
df[df["team"] == "TOR"]
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 7      240.0  36.0  80.0  0.450   7.0  18.0  0.389  27.0  39.0  0.692  ...
# 41     240.0  36.0  82.0  0.439  11.0  26.0  0.423  30.0  35.0  0.857  ...
# 84     240.0  41.0  90.0  0.456  11.0  25.0  0.440  13.0  20.0  0.650  ...
# 104    240.0  37.0  82.0  0.451   5.0  17.0  0.294  23.0  26.0  0.885  ...
# 123    240.0  33.0  79.0  0.418   5.0  14.0  0.357  32.0  39.0  0.821  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17615  240.0  38.0  89.0  0.427  11.0  32.0  0.344  10.0  12.0  0.833  ...
# 17631  265.0  38.0  86.0  0.442  13.0  35.0  0.371  12.0  18.0  0.667  ...
# 17651  240.0  37.0  88.0  0.420   8.0  34.0  0.235  28.0  35.0  0.800  ...
# 17661  240.0  42.0  82.0  0.512   8.0  31.0  0.258  11.0  13.0  0.846  ...
# 17677  240.0  35.0  89.0  0.393   7.0  35.0  0.200  20.0  25.0  0.800  ...
#
# ...

# %%
df["target"][pd.isnull(df["target"])] = 2
df["target"] = df["target"].astype(int, errors="ignore")
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_15092\2793819745.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["target"][pd.isnull(df["target"])] = 2

# %%
df["won"].value_counts()
# Out:
# False    8886
# True     8886
# Name: won, dtype: int64

# %%
df["target"].value_counts()
# Out:
# 1    8872
# 0    8870
# 2      30
# Name: target, dtype: int64

# %%
nulls = pd.isnull(df).sum()

# %%
nulls = nulls[nulls > 0]

# %%
valid_columns = df.columns[~df.columns.isin(nulls.index)]

# %%
valid_columns
# Out:
# Index(['mp', 'fg', 'fga', 'fg%', '3p', '3pa', '3p%', 'ft', 'fta', 'ft%',
#        ...
#        'usg%_max_opp', 'ortg_max_opp', 'drtg_max_opp', 'team_opp', 'total_opp',
#        'home_opp', 'season', 'date', 'won', 'target'],
#       dtype='object', length=142)

# %%
df = df[valid_columns].copy()

# %%
df
# Out:
#           mp    fg   fga    fg%    3p   3pa    3p%    ft   fta    ft%  ...  \
# 0      240.0  35.0  83.0  0.422   6.0  18.0  0.333  19.0  27.0  0.704  ...
# 1      240.0  38.0  94.0  0.404   9.0  29.0  0.310  10.0  17.0  0.588  ...
# 2      240.0  37.0  87.0  0.425   7.0  19.0  0.368  16.0  23.0  0.696  ...
# 3      240.0  41.0  96.0  0.427   9.0  30.0  0.300  20.0  22.0  0.909  ...
# 4      240.0  37.0  82.0  0.451   8.0  27.0  0.296  12.0  15.0  0.800  ...
# ...      ...   ...   ...    ...   ...   ...    ...   ...   ...    ...  ...
# 17767  240.0  34.0  85.0  0.400  15.0  38.0  0.395  14.0  19.0  0.737  ...
# 17768  240.0  41.0  88.0  0.466   9.0  40.0  0.225  13.0  15.0  0.867  ...
# 17769  240.0  31.0  75.0  0.413  11.0  32.0  0.344  21.0  31.0  0.677  ...
# 17770  240.0  34.0  80.0  0.425  11.0  28.0  0.393  11.0  12.0  0.917  ...
# 17771  240.0  38.0  92.0  0.413  19.0  46.0  0.413   8.0   8.0  1.000  ...
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.histplot(df['3p%'])
# Out:
# <AxesSubplot:xlabel='3p%', ylabel='Count'>

# %%
sns.histplot(df['+/-_max'])
# Out:
# <AxesSubplot:xlabel='+/-_max', ylabel='Count'>

# %%
sns.histplot(df['tov_max'])
# Out:
# <AxesSubplot:xlabel='tov_max', ylabel='Count'>

# %%
corrs = ['ft%','orb', 'blk','efg%','usg%','fga_max','ft_max','tov_max','+/-_max','ts%_max','drb%_max','trb%_max','tov%_max','usg%_max','mp_opp','fg_opp','3p_opp','fta_opp','blk_opp','ts%_opp','usg%_opp','fga_max_opp','fta_max_opp','stl_max_opp','blk_max_opp','pf_max_opp','drb%_max_opp','ast%_max_opp','stl%_max_opp','usg%_max_opp']

sns.heatmap(data = df[corrs].corr(), annot = False, cmap = 'coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Ridge

# %%
from sklearn.linear_model import RidgeClassifier
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

rr = RidgeClassifier(alpha=1)

split = TimeSeriesSplit(n_splits=3)

sfs = SequentialFeatureSelector(rr, 
                                n_features_to_select=30, 
                                direction="forward",
                                cv=split,
                                n_jobs=1
                               )

# %%
removed_columns = ["mp","season", "date", "won", "target", "team", "team_opp"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
sfs.fit(df[selected_columns], df["target"])
predictors = list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['ft%',
#  'orb',
#  'blk',
#  'efg%',
#  'usg%',
#  'fga_max',
#  'ft_max',
#  'tov_max',
#  '+/-_max',
#  'ts%_max',
#  'drb%_max',
#  'trb%_max',
#  'tov%_max',
#  'usg%_max',
#  'mp_opp',
#  'fg_opp',
#  '3p_opp',
#  'fta_opp',
#  'blk_opp',
#  'ts%_opp',
#  'usg%_opp',
#  'fga_max_opp',
#  'fta_max_opp',
#  'stl_max_opp',
#  'blk_max_opp',
#  'pf_max_opp',
#  'drb%_max_opp',
#  'ast%_max_opp',
#  'stl%_max_opp',
#  'usg%_max_opp']

# %%
def backtest(data, model, predictors, start=2, step=1):
    all_predictions = []
    
    seasons = sorted(data["season"].unique())
    
    for i in range(start, len(seasons), step):
        season = seasons[i]
        train = data[data["season"] < season]
        test = data[data["season"] == season]
        
        model.fit(train[predictors], train["target"])
        
        preds = model.predict(test[predictors])
        preds = pd.Series(preds, index=test.index)
        combined = pd.concat([test["target"], preds], axis=1)
        combined.columns = ["actual", "prediction"]
        
        all_predictions.append(combined)
    return pd.concat(all_predictions)

# %%
predictions = backtest(df, rr, predictors)

# %%
from sklearn.metrics import accuracy_score

accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.5448011499760421

# %%
df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %% [markdown]
# ### Logistic

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.model_selection import TimeSeriesSplit

lr = LogisticRegression()


sfs = SequentialFeatureSelector(lr, 
                                n_features_to_select=10, 
                                direction="forward",
                                cv=split,
                                n_jobs=1
                               )

# %%
removed_columns = ["mp","season", "date", "won", "target", "team", "team_opp"]
selected_columns = df.columns[~df.columns.isin(removed_columns)]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
df[selected_columns] = scaler.fit_transform(df[selected_columns])

# %%
sfs.fit(df[selected_columns], df["target"])
predictors = list(selected_columns[sfs.get_support()])

# %%
predictions = backtest(df, lr, predictors)

accuracy_score(predictions["actual"], predictions["prediction"])
df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier()

# %%
predictions = backtest(df, rf, predictors)

accuracy_score(predictions["actual"], predictions["prediction"])
df.groupby(["home"]).apply(lambda x: x[x["won"] == 1].shape[0] / x.shape[0])
# Out:
# home
# 0.0    0.428314
# 1.0    0.571686
# dtype: float64

# %%
df_rolling = df[list(selected_columns) + ["won", "team", "season"]]

def find_team_averages(team):
    rolling = team.rolling(10).mean()
    return rolling

df_rolling = df_rolling.groupby(["team", "season"], group_keys=False).apply(find_team_averages)
# Out:
# C:\Users\augus\AppData\Local\Temp\ipykernel_15092\1009080087.py:4: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['team'], dtype='object')
#   rolling = team.rolling(10).mean()

# %%
df_rolling
# Out:
#              fg       fga       fg%        3p       3pa       3p%        ft  \
# 0           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 4           NaN       NaN       NaN       NaN       NaN       NaN       NaN
# ...         ...       ...       ...       ...       ...       ...       ...
# 17767  0.381818  0.292647  0.428230  0.468966  0.477273  0.448100  0.434884
# 17768  0.502273  0.364706  0.517703  0.455172  0.481818  0.440736  0.320930
# 17769  0.354545  0.279412  0.404545  0.437931  0.465152  0.429572  0.434884
# 17770  0.354545  0.294118  0.389952  0.434483  0.459091  0.431710  0.406977
# 17771  0.484091  0.379412  0.482297  0.486207  0.507576  0.448812  0.316279
#
# ...

# %%
rolling_cols = [f"{col}_10" for col in df_rolling.columns]
df_rolling.columns = rolling_cols
df = pd.concat([df, df_rolling], axis=1)

# %%
df = df.dropna()
df
# Out:
#           mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    240.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    240.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    240.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    240.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    240.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...      ...       ...       ...       ...       ...       ...       ...
# 17767  240.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  240.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  240.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  240.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  240.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  stl%_max_opp_10  blk%_max_opp_10  \
# ...

# %%
def shift_col(team, col_name):
    next_col = team[col_name].shift(-1)
    return next_col

def add_col(df, col_name):
    return df.groupby("team", group_keys=False).apply(lambda x: shift_col(x, col_name))

df["home_next"] = add_col(df, "home")
df["team_opp_next"] = add_col(df, "team_opp")
df["date_next"] = add_col(df, "date")
df
# Out:
#           mp        fg       fga       fg%        3p       3pa       3p%  \
# 243    240.0  0.522727  0.382353  0.523923  0.344828  0.333333  0.457245
# 251    240.0  0.659091  0.426471  0.645933  0.620690  0.515152  0.562945
# 252    240.0  0.386364  0.382353  0.358852  0.206897  0.181818  0.445368
# 253    240.0  0.500000  0.382353  0.497608  0.344828  0.318182  0.475059
# 256    240.0  0.318182  0.132353  0.500000  0.275862  0.272727  0.432304
# ...      ...       ...       ...       ...       ...       ...       ...
# 17767  240.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 17768  240.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 17769  240.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
# 17770  240.0  0.340909  0.294118  0.373206  0.379310  0.363636  0.466746
# 17771  240.0  0.431818  0.470588  0.344498  0.655172  0.636364  0.490499
#
#              ft       fta       ft%  ...  usg%_max_opp_10  ortg_max_opp_10  \
# ...

# %%
full = df.merge(df[rolling_cols + ["team_opp_next", "date_next", "team"]], left_on=["team", "date_next"], right_on=["team_opp_next", "date_next"])
full
# Out:
#           mp        fg       fga       fg%        3p       3pa       3p%  \
# 0      240.0  0.477273  0.500000  0.375598  0.379310  0.348485  0.483373
# 1      240.0  0.340909  0.250000  0.413876  0.310345  0.257576  0.509501
# 2      290.0  0.409091  0.455882  0.330144  0.482759  0.515152  0.437055
# 3      265.0  0.545455  0.544118  0.416268  0.413793  0.454545  0.419240
# 4      240.0  0.340909  0.558824  0.186603  0.206897  0.469697  0.203088
# ...      ...       ...       ...       ...       ...       ...       ...
# 15769  240.0  0.545455  0.426471  0.511962  0.448276  0.469697  0.440618
# 15770  240.0  0.477273  0.455882  0.409091  0.517241  0.590909  0.414489
# 15771  240.0  0.340909  0.367647  0.313397  0.517241  0.515152  0.469121
# 15772  240.0  0.500000  0.411765  0.471292  0.310345  0.545455  0.267221
# 15773  240.0  0.272727  0.220588  0.344498  0.379310  0.424242  0.408551
#
#              ft       fta       ft%  ...  tov%_max_opp_10_y  \
# ...

# %%
full[["team_x", "team_opp_next_x", "team_y", "team_opp_next_y", "date_next"]]
# Out:
#       team_x team_opp_next_x team_y team_opp_next_y   date_next
# 0        SAC             TOR    TOR             SAC  2015-11-15
# 1        TOR             SAC    SAC             TOR  2015-11-15
# 2        CLE             DET    DET             CLE  2015-11-17
# 3        GSW             TOR    TOR             GSW  2015-11-17
# 4        DEN             NOP    NOP             DEN  2015-11-17
# ...      ...             ...    ...             ...         ...
# 15769    BOS             GSW    GSW             BOS  2022-06-10
# 15770    GSW             BOS    BOS             GSW  2022-06-13
# 15771    BOS             GSW    GSW             BOS  2022-06-13
# 15772    GSW             BOS    BOS             GSW  2022-06-16
# 15773    BOS             GSW    GSW             BOS  2022-06-16
#
# [15774 rows x 5 columns]

# %%
removed_columns = list(full.columns[full.dtypes == "object"]) + removed_columns
removed_columns
# Out:
# ['team_x',
#  'team_opp',
#  'date',
#  'team_opp_next_x',
#  'date_next',
#  'team_opp_next_y',
#  'team_y',
#  'mp',
#  'season',
#  'date',
#  'won',
#  'target',
#  'team',
#  'team_opp']

# %%
selected_columns = full.columns[~full.columns.isin(removed_columns)]
sfs.fit(full[selected_columns], full["target"])
# Out:
# SequentialFeatureSelector(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=3, test_size=None),
#                           estimator=LogisticRegression(),
#                           n_features_to_select=10, n_jobs=1)

# %%
predictors = list(selected_columns[sfs.get_support()])
predictors
# Out:
# ['drb_max',
#  'blk%_opp',
#  'ft%_max_opp',
#  'blk%_max_opp',
#  'ts%_max_10_x',
#  'ts%_max_opp_10_x',
#  'won_10_x',
#  'home_next',
#  'fg%_max_10_y',
#  'won_10_y']

# %%
predictions = backtest(full, rr, predictors)
accuracy_score(predictions["actual"], predictions["prediction"])
# Out:
# 0.6242227629088943
